# %% [markdown]
# # Load Library

# %%
# !pip install matplotlib --upgrade
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns

# %% [markdown]
# # Load Dataset

# %%
df = pd.read_csv('hotel_bookings_data.csv')

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2017          September
# 1  Resort Hotel            0        737               2017          September
# 2  Resort Hotel            0          7               2017          September
# 3  Resort Hotel            0         13               2017          September
# 4  Resort Hotel            0         14               2017          September
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_weekdays_nights  adults  ...  \
# 0                        0                         0       2  ...
# ...

# %%
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2018.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2017.000000
# 25%         0.000000      18.000000        2018.000000
# 50%         0.000000      69.000000        2018.000000
# 75%         1.000000     160.000000        2019.000000
# max         1.000000     737.000000        2019.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 29 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_weekdays_nights        119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %% [markdown]
# # Handling null value

# %%
# checking null data
counts = df.isna().sum().sort_values(ascending=False)
# check the percentage of empty data
percentages = round(df.isna().mean() * 100, 2).sort_values(ascending=False)
null_values = pd.concat([counts, percentages], axis=1, keys=["count", "%"])
null_values
# Out:
#                                  count      %
# company                         112593  94.31
# agent                            16340  13.69
# city                               488   0.41
# children                             4   0.00
# hotel                                0   0.00
# is_repeated_guest                    0   0.00
# total_of_special_requests            0   0.00
# required_car_parking_spaces          0   0.00
# adr                                  0   0.00
# customer_type                        0   0.00
# days_in_waiting_list                 0   0.00
# deposit_type                         0   0.00
# booking_changes                      0   0.00
# previous_bookings_not_canceled       0   0.00
# previous_cancellations               0   0.00
# market_segment                       0   0.00
# distribution_channel                 0   0.00
# is_canceled                          0   0.00
# meal                                 0   0.00
# ...

# %%
df['company'] = df['company'].fillna(0)
df['agent'] = df['agent'].fillna(0)
df['children'] = df['children'].fillna(0)
df['city'] = df['city'].fillna('unknown')

# %%
# checking null data
counts = df.isna().sum().sort_values(ascending=False)
# check the percentage of empty data
percentages = round(df.isna().mean() * 100, 2).sort_values(ascending=False)
null_values = pd.concat([counts, percentages], axis=1, keys=["count", "%"])
null_values
# Out:
#                                 count    %
# hotel                               0  0.0
# distribution_channel                0  0.0
# total_of_special_requests           0  0.0
# required_car_parking_spaces         0  0.0
# adr                                 0  0.0
# customer_type                       0  0.0
# days_in_waiting_list                0  0.0
# company                             0  0.0
# agent                               0  0.0
# deposit_type                        0  0.0
# booking_changes                     0  0.0
# previous_bookings_not_canceled      0  0.0
# previous_cancellations              0  0.0
# is_repeated_guest                   0  0.0
# market_segment                      0  0.0
# is_canceled                         0  0.0
# city                                0  0.0
# meal                                0  0.0
# babies                              0  0.0
# children                            0  0.0
# adults                              0  0.0
# ...

# %% [markdown]
# # Replace inappropriate values

# %%
df['meal'].value_counts()
# Out:
# Breakfast     92310
# Dinner        14463
# No Meal       10650
# Undefined      1169
# Full Board      798
# Name: meal, dtype: int64

# %%
# replace the 'Undefined' value in meal columns to 'No Meal'
df = df.replace({'meal': {'Undefined':'No Meal'}})
df['meal'].value_counts()
# Out:
# Breakfast     92310
# Dinner        14463
# No Meal       11819
# Full Board      798
# Name: meal, dtype: int64

# %%
# replace few columns data type from float64 to int64
df[['children', 'agent', 'company', 'days_in_waiting_list', 'required_car_parking_spaces', 'total_of_special_requests']] = df[['children', 'agent', 'company', 'days_in_waiting_list', 'required_car_parking_spaces', 'total_of_special_requests']].astype('int64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 29 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_weekdays_nights        119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119390 non-null  int64
#  11  babies                          119390 non-null  int64
# ...

# %%
df_clean = df.copy()

# %% [markdown]
# # Drop unnecessary data

# %%
# checking the total guest and total stay duration, if 0 
df_clean['total_guest'] = df_clean['adults'] + df_clean['children'] + df_clean['babies']
df_clean['total_stay_duration'] = df_clean['stays_in_weekend_nights'] + df_clean['stays_in_weekdays_nights']

print(f'Number of data rows with 0 total guest: {df_clean[df_clean["total_guest"] == 0].shape[0]} out of {len(df_clean)} data')
print(f'Number of data rows with 0 total stay duration: {df_clean[df_clean["total_stay_duration"] == 0].shape[0]} out of {len(df_clean)} data')
# Out:
# Number of data rows with 0 total guest: 180 out of 119390 data
# Number of data rows with 0 total stay duration: 715 out of 119390 data

# %%
df_clean_final = df_clean[(df_clean['total_guest'] > 0) & (df_clean['total_stay_duration'] > 0)]

print(f'Number of data before filtering : {len(df_clean)} rows')
print(f'Number of data after filtering : {len(df_clean_final)} rows')
# Out:
# Number of data before filtering : 119390 rows
# Number of data after filtering : 118565 rows

# %%
df_fix = df_clean_final.copy()

# %% [markdown]
# # EDA

# %%
df_fix.groupby(['hotel', 'arrival_date_year', 'arrival_date_month']).agg({'is_canceled' : 'count'})
# Out:
#                                                    is_canceled
# hotel        arrival_date_year arrival_date_month
# City Hotel   2017              December                   3368
#                                February                   1637
#                                January                    1225
#                                November                   3516
#                                October                    2471
#                                September                  1393
#              2018              April                      2347
#                                August                     3914
#                                December                   4186
#                                February                   2460
#                                January                    3084
#                                July                       3640
#                                June                       3549
# ...

# %%
# create aggregate table to show total hotel booking per month based on hotel category
df_table = df_fix.groupby(['hotel', 'arrival_date_year', 'arrival_date_month']).agg({'is_canceled' : 'count'}).reset_index()

# %%
# create amount of year based on hotel category and month
df_year = df_table.groupby(['hotel', 'arrival_date_month']).agg({'arrival_date_year':'count'})
df_table = df_table.merge(df_year, on=['hotel', 'arrival_date_month'])
df_table
# Out:
#            hotel  arrival_date_year_x arrival_date_month  is_canceled  \
# 0     City Hotel                 2017           December         3368
# 1     City Hotel                 2018           December         4186
# 2     City Hotel                 2017           February         1637
# 3     City Hotel                 2018           February         2460
# 4     City Hotel                 2017            January         1225
# 5     City Hotel                 2018            January         3084
# 6     City Hotel                 2017           November         3516
# 7     City Hotel                 2018           November         3861
# 8     City Hotel                 2017            October         2471
# 9     City Hotel                 2018            October         3362
# 10    City Hotel                 2019            October         3119
# 11    City Hotel                 2017          September         1393
# ...

# %%
# create sum of booking based on hotel category and month
df_booking_sum = df_table.groupby(['hotel', 'arrival_date_month']).agg({'is_canceled' : 'sum'})
df_table = df_table.merge(df_booking_sum, on=['hotel', 'arrival_date_month'])
df_table = df_table.rename(columns = {'arrival_date_year_x' : 'arrival_date_year', 'is_canceled_x' : 'num_of_booking', 'arrival_date_year_y' : 'amount_of_year', 'is_canceled_y' : 'sum_of_booking'})


df_table['avg_num_booking'] = round(df_table['sum_of_booking']/df_table['amount_of_year'])
df_table
# Out:
#            hotel  arrival_date_year arrival_date_month  num_of_booking  \
# 0     City Hotel               2017           December            3368
# 1     City Hotel               2018           December            4186
# 2     City Hotel               2017           February            1637
# 3     City Hotel               2018           February            2460
# 4     City Hotel               2017            January            1225
# 5     City Hotel               2018            January            3084
# 6     City Hotel               2017           November            3516
# 7     City Hotel               2018           November            3861
# 8     City Hotel               2017            October            2471
# 9     City Hotel               2018            October            3362
# 10    City Hotel               2019            October            3119
# 11    City Hotel               2017          September            1393
# ...

# %%
#create percentage column
df_month_percent = df_table[['hotel', 'arrival_date_month', 'avg_num_booking']]

#drop duplicate data
df_month_percent = df_month_percent.drop_duplicates()

#summarize total of avg num booking based on hotel type
df_part = df_month_percent.groupby('hotel').agg({'avg_num_booking':'sum'})
df_month_percent = df_month_percent.merge(df_part, on='hotel')
df_month_percent = df_month_percent.rename(columns = {'avg_num_booking_x' : 'avg_num_booking', 'avg_num_booking_y' : 'total_avg_booking'})

#create percentage column based on avg num booking per hotel type
df_month_percent['percentage'] = round((df_month_percent['avg_num_booking']/df_month_percent['total_avg_booking'])*100, 2)
df_month_percent =  df_month_percent.replace({'arrival_date_month': {'January':1, 'February':2, 'March':3, 'April':4, 'May':5, 'June':6, 
                                           'July':7, 'August':8, 'September':9, 'October':10, 'November':11, 'December':12}})
df_month_percent.sort_values('arrival_date_month', ascending=True)
# Out:
#            hotel  arrival_date_month  avg_num_booking  total_avg_booking  \
# 2     City Hotel                   1           2154.0            36614.0
# 14  Resort Hotel                   1           1202.0            18268.0
# 1     City Hotel                   2           2048.0            36614.0
# 13  Resort Hotel                   2           1296.0            18268.0
# 22  Resort Hotel                   3           1080.0            18268.0
# 10    City Hotel                   3           1856.0            36614.0
# 18  Resort Hotel                   4           1540.0            18268.0
# 6     City Hotel                   4           2458.0            36614.0
# 11    City Hotel                   5           3206.0            36614.0
# 23  Resort Hotel                   5           1652.0            18268.0
# 21  Resort Hotel                   6           1794.0            18268.0
# 9     City Hotel                   6           3729.0            36614.0
# ...

# %%
fig, ax = plt.subplots(figsize=(20, 8))
plt.title("Average Number of Hotel Bookings per Month Over Year\nBased on Hotel Types", fontsize=15, color='black', weight='bold', pad=80)
plt.text(x=-1.5, y=5250, s="June, July, and August were the months with the most hotel bookings. City hotels reached the highest average number of hotel bookings of 11.18% in July and resort hotels reached 9.82% in June.\nThis can happen because that month is the school vacation season. An increase in the number of bookings also occurred in December with city hotels by 10.32% and resort hotels by 9.61%.\nThis can occur due to the Christmas and New Year holidays.", fontsize=12, fontstyle='italic')
sns.barplot(x='arrival_date_month', y='avg_num_booking', data=df_month_percent, hue='hotel', edgecolor='black', palette='muted')

plt.xlabel('Month(s)', fontsize=11)
plt.xticks(np.arange(12), ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.ylabel('Average Number of Booking', fontsize=11)
plt.ylim(0, 5000)

plt.bar_label(ax.containers[0], padding=2)
plt.bar_label(ax.containers[1], padding=2)

plt.axvline(4.5, ls='--', color='green')
plt.axvline(7.5, ls='--', color='green')
plt.stackplot(np.arange(4.5,8.5), [[5000]], color='green', alpha=0.3)
plt.text(x=5.3, y=4750, s='School Vacation Season', fontsize=14, color='green', va='center')

plt.axvline(10.5, ls='--', color='red')
plt.axvline(11.5, ls='--', color='red')
plt.stackplot(np.arange(10.5,12.5), [[5000]], color='pink', alpha=0.3)
plt.text(x=10.65, y=4650, s='Christmas\nNew Year\n Holiday', fontsize=14, color='red', va='center')

plt.bar_label(ax.containers[0], ['5.88%', '5.59%', '5.07%', '6.71%', '8.76%', '10.18%', '11.18%', '10.75%', '7.33%', '8.15%', '10.07%', '10.32%'], label_type='center', color='white', weight='bold', fontsize=8)
plt.bar_label(ax.containers[1], ['6.58%', '7.09%', '5.91%', '8.43%', '9.04%', '9.82%', '9.63%', '8.25%', '8.27%', '8.87%', '8.48%', '9.61%'], label_type='center', color='white', weight='bold', fontsize=8)

sns.despine()
plt.tight_layout()
plt.savefig('avg_num_booking.png', dpi=200)

# %% [markdown]
# ## **Impact Analysis of Stay Duration on Hotel Bookings Cancellation Rates**

# %%
# grouping the total stay duration into week

def stay_duration_group(x):
  if x['total_stay_duration'] >= 1 and x['total_stay_duration'] <= 7:
    group = '1 weeks'
  elif x['total_stay_duration'] >= 8 and x['total_stay_duration'] <= 14:
    group =  '2 weeks'
  elif x['total_stay_duration'] >= 15 and x['total_stay_duration'] <= 21:
    group =  '3 weeks'
  else:
    group = '4 weeks'
  return group  
  
df_fix['total_stay_duration_group'] = df_fix.apply(lambda x: stay_duration_group(x), axis = 1)

# %%
df_fix['total_stay_duration_group'].value_counts()
# Out:
# 1 weeks    113339
# 2 weeks      4797
# 3 weeks       274
# 4 weeks       155
# Name: total_stay_duration_group, dtype: int64

# %%
#create num_of_booking columns
df_sd = df_fix.groupby(['hotel', 'total_stay_duration_group', 'is_canceled']).agg({'customer_type' : 'count'}).reset_index()
df_sd.rename(columns={'customer_type' : 'num_of_booking'}, inplace=True)


# create sum_of_booking columns
df_sum = df_sd.groupby(['hotel', 'total_stay_duration_group']).agg({'num_of_booking' : 'sum'}).reset_index()
df_sum.rename(columns={'num_of_booking' : 'sum_of_booking'}, inplace=True)
df_sd = df_sd.merge(df_sum, on=['hotel', 'total_stay_duration_group'])

#create cancellation rate percentage
df_sd['cancellation_rate'] = round((df_sd['num_of_booking']/df_sd['sum_of_booking'])*100, 2)
df_sd
# Out:
#            hotel total_stay_duration_group  is_canceled  num_of_booking  \
# 0     City Hotel                    1 week            0           45287
# 1     City Hotel                    1 week            1           32391
# 2     City Hotel                   2 weeks            0             511
# 3     City Hotel                   2 weeks            1             558
# 4     City Hotel                   3 weeks            0              29
# 5     City Hotel                   3 weeks            1              76
# 6     City Hotel                   4 weeks            0               6
# 7     City Hotel                   4 weeks            1              41
# 8   Resort Hotel                    1 week            0           25754
# 9   Resort Hotel                    1 week            1            9907
# 10  Resort Hotel                   2 weeks            0            2650
# 11  Resort Hotel                   2 weeks            1            1078
# ...

# %%
#filter the data that booking has been canceled

df_plot = df_sd[df_sd['is_canceled'] == 1].sort_values('total_stay_duration_group', ascending=True)
df_plot
# Out:
#            hotel total_stay_duration_group  is_canceled  num_of_booking  \
# 1     City Hotel                    1 week            1           32391
# 9   Resort Hotel                    1 week            1            9907
# 3     City Hotel                   2 weeks            1             558
# 11  Resort Hotel                   2 weeks            1            1078
# 5     City Hotel                   3 weeks            1              76
# 13  Resort Hotel                   3 weeks            1              79
# 7     City Hotel                   4 weeks            1              41
# 15  Resort Hotel                   4 weeks            1              46
#
#     sum_of_booking  cancellation_rate
# 1            77678              41.70
# 9            35661              27.78
# 3             1069              52.20
# 11            3728              28.92
# 5              105              72.38
# 13             169              46.75
# 7               47              87.23
# ...

# %%
fig, ax = plt.subplots(figsize=(10,6))
plt.title('There is a positive correlation between the duration of stay and\nthe cancellation rate of hotel reservations', fontsize=15, color='black', weight='bold', pad=80)
plt.text(x=-1, y=110, s="The longer the customer's stay, the higher the booking cancellation rate.\nThe most canceled duration of stay for city hotels occurs at the duration of 4 weeks.\nWhile the most canceled duration of stay for resort hotels occurs in the duration of 3 weeks.", fontsize=12, fontstyle='italic')

sns.barplot(x='total_stay_duration_group', y='cancellation_rate', data=df_plot, hue='hotel', edgecolor='black', palette='muted')

sns.regplot(x=np.arange(0, len(df_plot[df_plot['hotel'] == 'City Hotel'])), y='cancellation_rate', 
            data=df_plot[df_plot['hotel'] == 'City Hotel'], scatter=False, label = 'Trend City Hotel', truncate=False)
sns.regplot(x=np.arange(0, len(df_plot[df_plot['hotel'] == 'City Hotel'])), y='cancellation_rate', 
            data=df_plot[df_plot['hotel'] == 'Resort Hotel'], scatter=False, label='Trend Resort Hotel', truncate=False)

plt.xlabel('Stay Duration(s)', fontsize=11)
plt.ylabel('Cancellation Rate(%)', fontsize=11)
plt.ylim(0, 100)

plt.bar_label(ax.containers[0], padding=5)
plt.bar_label(ax.containers[1], padding=2)

sns.despine()
plt.tight_layout()
plt.savefig('stay_duration.png', dpi=200)

# %% [markdown]
# ## **Impact Analysis of Lead Time on Hotel Bookings Cancellation Rate**

# %%
def lead_time_group(x):
  if x['lead_time'] <= 30:
    lead_time = '1 Month'
  elif x['lead_time'] >= 31 and x['lead_time'] <= 120:
    lead_time = '2-4 Months'
  elif x['lead_time'] >= 121 and x['lead_time'] <= 210:
    lead_time = '5-7 Months'
  elif x['lead_time'] >= 211 and x['lead_time'] <= 300:
    lead_time = '8-10 Months'
  elif x['lead_time'] >= 301 and x['lead_time'] <= 360:
    lead_time = '11-12 Months'
  else:
    lead_time = '12 Months++'
  return lead_time

df_fix['lead_time_group'] = df_fix.apply(lambda x: lead_time_group(x), axis = 1)

# %%
df_fix['lead_time_group'].value_counts()
# Out:
# 2-4 Months      39851
# 1 Month         38094
# 5-7 Months      21619
# 8-10 Months     11122
# 11-12 Months     4467
# 12 Months++      3412
# Name: lead_time_group, dtype: int64

# %%
df_lt = df_fix.groupby(['hotel', 'lead_time_group', 'is_canceled']).agg({'agent' : 'count'}).reset_index()
df_lt.rename(columns={'agent' : 'num_of_booking'}, inplace=True)

# create sum_of_booking columns
df_sum = df_lt.groupby(['hotel', 'lead_time_group']).agg({'num_of_booking' : 'sum'}).reset_index()
df_sum.rename(columns={'num_of_booking' : 'sum_of_booking'}, inplace=True)
df_lt = df_lt.merge(df_sum, on=['hotel', 'lead_time_group'])

#create cancellation rate percentage
df_lt['cancellation_rate'] = round((df_lt['num_of_booking']/df_lt['sum_of_booking'])*100, 2)
df_lt
# Out:
#            hotel lead_time_group  is_canceled  num_of_booking  sum_of_booking  \
# 0     City Hotel         1 Month            0           17848           23022
# 1     City Hotel         1 Month            1            5174           23022
# 2     City Hotel    11-12 Months            0             731            3339
# 3     City Hotel    11-12 Months            1            2608            3339
# 4     City Hotel     12 Months++            0             790            2864
# 5     City Hotel     12 Months++            1            2074            2864
# 6     City Hotel      2-4 Months            0           16406           28189
# 7     City Hotel      2-4 Months            1           11783           28189
# 8     City Hotel      5-7 Months            0            7298           14349
# 9     City Hotel      5-7 Months            1            7051           14349
# 10    City Hotel     8-10 Months            0            2760            7136
# ...

# %%
#filter the data that booking has been canceled
df_plot1 = df_lt[df_lt['is_canceled'] == 1].sort_values('lead_time_group', ascending=True)
df_plot1
# Out:
#            hotel lead_time_group  is_canceled  num_of_booking  sum_of_booking  \
# 1     City Hotel         1 Month            1            5174           23022
# 13  Resort Hotel         1 Month            1            1976           15072
# 3     City Hotel    11-12 Months            1            2608            3339
# 15  Resort Hotel    11-12 Months            1             513            1128
# 5     City Hotel     12 Months++            1            2074            2864
# 17  Resort Hotel     12 Months++            1             214             548
# 7     City Hotel      2-4 Months            1           11783           28189
# 19  Resort Hotel      2-4 Months            1            3999           11662
# 9     City Hotel      5-7 Months            1            7051           14349
# 21  Resort Hotel      5-7 Months            1            2685            7270
# 11    City Hotel     8-10 Months            1            4376            7136
# ...

# %%
fig, ax = plt.subplots(figsize=(10, 6))
plt.title("Hotel booking cancellation rate\nper lead time by hotel type", fontsize=15, color='black', weight='bold', pad=90)
plt.text(x=-1, y=105, s="Both types of hotels have the lowest cancellation rate at\na lead time of 1 month (city hotel =22.47%, resort hotel = 13.11%),\nwhile at a lead time of 11-12 months there is the highest cancellation rate\n(city hotel = 78.11%, resort hotel = 45.48%).", fontsize=12, fontstyle='italic')
sns.barplot(x='lead_time_group', y='cancellation_rate', data=df_plot1, hue='hotel', order=['1 Month', '2-4 Months', '5-7 Months', '8-10 Months', '11-12 Months', '12 Months++'], edgecolor='black', palette='muted')

plt.xlabel('Lead Time(s)', fontsize=11)
plt.ylabel('Cancellation Rate(%)', fontsize=11)
plt.ylim(0, 100)

plt.bar_label(ax.containers[0], padding=2)
plt.bar_label(ax.containers[1], padding=2)

plt.axvline(3.5, ls='--', color='red')
plt.axvline(4.5, ls='--', color='red')
plt.stackplot(np.arange(3.5,5.5), [[100]], color='red', alpha=0.3)
plt.text(x=3.75, y=93, s='Highest\nRate', fontsize=14, color='red', va='center')

plt.axvline(0.5, ls='--', color='green')
plt.axvline(-0.5, ls='--', color='green')
plt.stackplot(np.arange(-0.5,1.5), [[100]], color='green', alpha=0.3)
plt.text(x=-0.25, y=93, s='Lowest\nRate', fontsize=14, color='green', va='center')

plt.legend(title='Hotel Type', prop={'size':8}, loc=1)

sns.despine()
plt.tight_layout()
plt.savefig('leadtime.png', dpi=200)
